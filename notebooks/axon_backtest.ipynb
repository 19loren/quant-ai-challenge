# %%
# setup
import pandas as pandas
import yfinance as yf
from pathlib import Path

from src/config.py import *
# Out:
#   Cell In[3], line 6
#     from src/config.py import *
#             ^
# SyntaxError: invalid syntax
